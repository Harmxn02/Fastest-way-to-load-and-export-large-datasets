# %% [markdown]
# # cuDF log test
#
# You can see how cuDF utilises your GPU, so this notebook just shows that

# %%
# %load_ext cudf.pandas

# %%
# %%cudf.pandas.profile
#
# import pandas as pd
#
# data = pd.read_csv("../data/concat.csv")
# data = data.drop(columns=[" Destination Port"])
#
# data.head(200)
# Out:
#       Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0                 4                   2                        0
# 1                 1                   2                        0
# 2                 1                   2                        0
# 3                 1                   2                        0
# 4                 3                   2                        0
# ..              ...                 ...                      ...
# 195        67398647                  23                        0
# 196        64022097                   4                        4
# 197          112537                  49                       30
# 198           37485                   1                        1
# 199        82470362                  66                       45
#
#      Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                             12                             0
# ...
